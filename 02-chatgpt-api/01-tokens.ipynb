# %%
from openai import OpenAI
client = OpenAI()

# %%
model = "gpt-4o"

def get_completion(prompt):
  messages = [{ "role": "user", "content": prompt }]
  response = client.chat.completions.create(
    model=model,
    messages=messages,
    temperature=0 # this is the degree of randomness of the model's output
  )
  return response.choices[0].message.content

def get_completion_from_messages(messages, temperature=0):
  response = client.chat.completions.create(
    model=model,
    messages=messages,
    temperature=temperature # this is the degree of randomness of the model's output
  )
  return response.choices[0].message.content

# %%
response = get_completion("What is the capital of France?")
print(response)
# Out:
# The capital of France is Paris.

# %% [markdown]
# ## Tokens

# %%
response = get_completion("Take the letters in lollipop \
and reverse them")
print(response)
# Out:
# The word "lollipop" reversed is "popillol."

# %%
response = get_completion("""Take the letters in \
l-o-l-l-i-p-o-p and reverse them""")
print(response)
# Out:
# Reversing the letters in "lollipop" gives you "popillol."

# %%
messages =  [
  {
    'role': 'system',
    'content': 'All your responses must be one sentence long.'
  },
  {
    'role': 'user',
    'content': 'write me a story about a happy carrot'
  },
]
response = get_completion_from_messages(messages, temperature = 1)
print(response)
# Out:
# Once upon a time, in a vibrant vegetable garden, there lived a cheerful carrot named Carl who loved to dance under the warm sun, making all the other vegetables smile with his infectious happiness.

# %%
def get_completion_and_token_count(messages,
                                   model="gpt-4o",
                                   temperature=0,
                                   max_tokens=500):

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
    )

    content = response.choices[0].message.content

    token_dict = {
        'prompt_tokens': response.usage.prompt_tokens,
        'completion_tokens': response.usage.completion_tokens,
        'total_tokens': response.usage.total_tokens,
    }

    return content, token_dict

# %%
messages = [
  {
    'role': 'system',
    'content': "You are an assistant who responds in the style of Dr Seuss"
  },
  {
    'role': 'user',
    'content':"write me a very short poem about a happy carrot"
  },
]
response, token_dict = get_completion_and_token_count(messages)
print(response)
print(token_dict)
# Out:
# In a garden so merry, where the sun loves to play,
# Lived a carrot named Carrie, who danced every day.
# With a top hat of green and a smile oh so wide,
# She twirled in the soil, full of joy and of pride.
#
# "Oh, I'm just a carrot, but happy as can be,
# For the earth is my home, and it nourishes me!"
# She giggled and wiggled, in her orange delight,
# A happy little carrot, from morning till night!
# {'prompt_tokens': 34, 'completion_tokens': 109, 'total_tokens': 143}
